# %% [markdown]
# ### Dash
#
# - Instalar o dash
#
#
# Estrutura Básica
# - plotly -> gráficos
# - Flask -> aplicação

# %% [markdown]
# ### Como funciona o Dash
#
# - Layout
#     - HTML -> textos, imagens, espaços
#     - Dash Components (Core Components) -> gráficos, botões que mexem em gráficos, coisas do dashboard
# - Callbacks

# %%
from dash import Dash, html, dcc
import plotly.express as px
import pandas as pd

app = Dash(__name__) # Criando seu Aplicativo Dash

# assume you have a "long-form" data frame
# see https://plotly.com/python/px-arguments/ for more options
df = pd.read_excel('Vendas.xlsx')

# df = tabela = dataframe

# plotly
fig = px.bar(df, x="Produto", y="Quantidade", color="ID Loja", barmode="group")

# css
app.layout = html.Div(children=[
    html.H1(children='Meu Dashboard'),

    html.Div(children='''
        Dashboard de Vendas em Python.
    '''),

    html.H3(children='Vendas de cada Produto por Loja'),

    dcc.Graph(
        id='vendas_por_loja',figure=fig),        
],style={'text-align':'center'})

# callbacks


# Colocando ( seu Dashboard ) no ar
if __name__ == '__main__': 
    app.run_server(debug=False)
# Out:
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:8050/ (Press CTRL+C to quit)
# 127.0.0.1 - - [05/May/2022 20:19:34] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [05/May/2022 20:19:34] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [05/May/2022 20:19:34] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [05/May/2022 20:19:34] "GET /_dash-component-suites/dash/dcc/async-graph.js HTTP/1.1" 200 -
# 127.0.0.1 - - [05/May/2022 20:19:34] "GET /_dash-component-suites/dash/dcc/async-plotlyjs.js HTTP/1.1" 200 -

# %% [markdown]
# ### Adicionar mais um Gráfico

# %%
from dash import Dash, html, dcc
import plotly.express as px
import pandas as pd

app = Dash(__name__) # Criando seu Aplicativo Dash

# assume you have a "long-form" data frame
# see https://plotly.com/python/px-arguments/ for more options
df = pd.read_excel('Vendas.xlsx')

# df = tabela = dataframe

# plotly
fig = px.bar(df, x="Produto", y="Quantidade", color="ID Loja", barmode="group")
fig2 = px.scatter(df, x="Quantidade", y="Valor Final", color="Produto", size='Valor Unitário', size_max = 60)

# css
app.layout = html.Div(children=[
    html.H1(children='Meu Dashboard'),

    html.Div(children='''
        Dashboard de Vendas em Python.
    '''),

    html.H3(children='Vendas de cada Produto por Loja'),

    dcc.Graph(id='vendas_por_loja',figure=fig), 
    dcc.Graph(id='grafico2',figure=fig2),       
],style={'text-align':'center'})

# callbacks


# Colocando ( seu Dashboard ) no ar
if __name__ == '__main__': 
    app.run_server(debug=False)
# Out:
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:8050/ (Press CTRL+C to quit)
# 127.0.0.1 - - [05/May/2022 20:19:49] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [05/May/2022 20:19:49] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [05/May/2022 20:19:49] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [05/May/2022 20:19:49] "GET /_favicon.ico?v=2.3.1 HTTP/1.1" 200 -
# 127.0.0.1 - - [05/May/2022 20:19:49] "GET /_dash-component-suites/dash/dcc/async-graph.js HTTP/1.1" 200 -
# 127.0.0.1 - - [05/May/2022 20:19:49] "GET /_dash-component-suites/dash/dcc/async-plotlyjs.js HTTP/1.1" 200 -

# %% [markdown]
# #### Inserindo um botão com um callback

# %%
from dash import Dash, html, dcc, Input, Output
import plotly.express as px
import pandas as pd


app = Dash(__name__) # criando o seu aplicativo Dash


# assume you have a "long-form" data frame
# see https://plotly.com/python/px-arguments/ for more options
df = pd.read_excel("Vendas.xlsx")

# df = tabela = dataframe

# plotly
fig = px.bar(df, x="Produto", y="Quantidade", color="ID Loja", barmode="group")
fig2 = px.scatter(df, x="Quantidade", y="Valor Final", color="Produto", size="Valor Unitário", size_max=60)


# lista_marcas = ["Treinamentos", "Programação", "Todas"]
lista_marcas = list(df["Marca"].unique())
lista_marcas.append("Todas")

# layout
app.layout = html.Div(children=[
    html.H1(children='Meu Dashboard'),

    html.Div(children='''
        Dashboard de Vendas em Python
    '''),
    
    html.H3(children="Vendas de cada Produto por Loja", id="subtitulo"),
    
    dcc.RadioItems(lista_marcas, value="Todas", id='selecao_marcas'),
    dcc.Graph(id='vendas_por_loja',figure=fig),
    dcc.Graph(id='distribuicao_vendas', figure=fig2),
    
    
], style={"text-align": "center"})

# callbacks --> Dar funcionalidade pro nosso Dashboard (conecta os botões com os gráficos)

@app.callback(
    Output('subtitulo','children'), # eu quero modificar (eu quero que o botão do Input modifique)
    Input('selecao_marcas','value'), # quem está modificando/de onde eu quero pegar a informação/que tá fazendo um filtro.
)
def selecionar_marca(marca): 
    if marca == 'Todas':
        texto = 'Vendas de cada Produto por Loja'
    else:
        texto = f'Vendas de cada Produto por Loja da Marca {marca}'
    return texto

# colocando o seu site (seu dashboard) no ar
if __name__ == '__main__':
    app.run_server(debug=False)
# Out:
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:8050/ (Press CTRL+C to quit)
# 127.0.0.1 - - [05/May/2022 20:49:37] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [05/May/2022 20:49:37] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [05/May/2022 20:49:37] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [05/May/2022 20:49:37] "GET /_favicon.ico?v=2.3.1 HTTP/1.1" 200 -
# 127.0.0.1 - - [05/May/2022 20:49:37] "GET /_dash-component-suites/dash/dcc/async-graph.js HTTP/1.1" 200 -
# 127.0.0.1 - - [05/May/2022 20:49:37] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [05/May/2022 20:49:37] "GET /_dash-component-suites/dash/dcc/async-plotlyjs.js HTTP/1.1" 200 -
# 127.0.0.1 - - [05/May/2022 20:49:40] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [05/May/2022 20:49:46] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [05/May/2022 20:49:48] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [05/May/2022 20:49:50] "POST /_dash-update-component HTTP/1.1" 200 -

# %% [markdown]
# #### Autenticação
#
# * Colocar uma Senha em nosso Dashboard

# %%
from dash import Dash, html, dcc, Input, Output
import plotly.express as px
import pandas as pd
import dash_auth

USUARIOS = {
    'Ferreira': '123456',
}


app = Dash(__name__) # criando o seu aplicativo Dash
auth = dash_auth.BasicAuth(app, USUARIOS)

# assume you have a "long-form" data frame
# see https://plotly.com/python/px-arguments/ for more options
df = pd.read_excel("Vendas.xlsx")

# df = tabela = dataframe

# plotly
fig = px.bar(df, x="Produto", y="Quantidade", color="ID Loja", barmode="group")
fig2 = px.scatter(df, x="Quantidade", y="Valor Final", color="Produto", size="Valor Unitário", size_max=60)


# lista_marcas = ["Treinamentos", "Programação", "Todas"]
lista_marcas = list(df["Marca"].unique())
lista_marcas.append("Todas")

# layout
app.layout = html.Div(children=[
    html.H1(children='Meu Dashboard'),

    html.Div(children='''
        Dashboard de Vendas em Python
    '''),
    
    html.H3(children="Vendas de cada Produto por Loja", id="subtitulo"),
    
    dcc.RadioItems(lista_marcas, value="Todas", id='selecao_marcas'),
    dcc.Graph(id='vendas_por_loja',figure=fig),
    dcc.Graph(id='distribuicao_vendas', figure=fig2),
    
    
], style={"text-align": "center"})

# callbacks --> Dar funcionalidade pro nosso Dashboard (conecta os botões com os gráficos)

@app.callback(
    Output('subtitulo','children'), # eu quero modificar (eu quero que o botão do Input modifique)
    Input('selecao_marcas','value'), # quem está modificando/de onde eu quero pegar a informação/que tá fazendo um filtro.
)
def selecionar_marca(marca): 
    if marca == 'Todas':
        texto = 'Vendas de cada Produto por Loja'
    else:
        texto = f'Vendas de cada Produto por Loja da Marca {marca}'
    return texto

# colocando o seu site (seu dashboard) no ar
if __name__ == '__main__':
    app.run_server(debug=False)
# Out:
# C:\Users\PC\anaconda3\lib\site-packages\dash_auth\plotly_auth.py:16: UserWarning:
#
#
# The dash_html_components package is deprecated. Please replace
# `import dash_html_components as html` with `from dash import html`
#
# C:\Users\PC\anaconda3\lib\site-packages\dash_auth\plotly_auth.py:17: UserWarning:
#
#
# The dash_core_components package is deprecated. Please replace
# `import dash_core_components as dcc` with `from dash import dcc`
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:8050/ (Press CTRL+C to quit)
# 127.0.0.1 - - [05/May/2022 20:58:32] "GET / HTTP/1.1" 401 -
# 127.0.0.1 - - [05/May/2022 20:58:42] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [05/May/2022 20:58:42] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [05/May/2022 20:58:42] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [05/May/2022 20:58:42] "GET /_favicon.ico?v=2.3.1 HTTP/1.1" 200 -
# 127.0.0.1 - - [05/May/2022 20:58:42] "GET /_dash-component-suites/dash/dcc/async-graph.js HTTP/1.1" 200 -
# 127.0.0.1 - - [05/May/2022 20:58:42] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [05/May/2022 20:58:42] "GET /_dash-component-suites/dash/dcc/async-plotlyjs.js HTTP/1.1" 200 -
# 127.0.0.1 - - [05/May/2022 20:58:49] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [05/May/2022 20:58:50] "POST /_dash-update-component HTTP/1.1" 200 -

# %% [markdown]
# #### Editar com o MESMO botão mais de 1 elemento

# %%
from dash import Dash, html, dcc, Input, Output
import plotly.express as px
import pandas as pd
import dash_auth

USUARIOS = {
    'Ferreira': '123456',
}


app = Dash(__name__) # criando o seu aplicativo Dash
auth = dash_auth.BasicAuth(app, USUARIOS)

# assume you have a "long-form" data frame
# see https://plotly.com/python/px-arguments/ for more options
df = pd.read_excel("Vendas.xlsx")

# df = tabela = dataframe

# plotly
fig = px.bar(df, x="Produto", y="Quantidade", color="ID Loja", barmode="group")
fig2 = px.scatter(df, x="Quantidade", y="Valor Final", color="Produto", size="Valor Unitário", size_max=60)


# lista_marcas = ["Treinamentos", "Programação", "Todas"]
lista_marcas = list(df["Marca"].unique())
lista_marcas.append("Todas")

# layout
app.layout = html.Div(children=[
    html.H1(children='Meu Dashboard'),

    html.Div(children='''
        Dashboard de Vendas em Python
    '''),
    
    html.H3(children="Vendas de cada Produto por Loja", id="subtitulo"),
    
    dcc.RadioItems(lista_marcas, value="Todas", id='selecao_marcas'),
    dcc.Graph(id='vendas_por_loja',figure=fig),
    dcc.Graph(id='distribuicao_vendas', figure=fig2),
    
    
], style={"text-align": "center"})

# callbacks --> Dar funcionalidade pro nosso Dashboard (conecta os botões com os gráficos)

@app.callback(
    Output('subtitulo','children'), # eu quero modificar (eu quero que o botão do Input modifique)
    Output('vendas_por_loja', 'figure'),
    Output('distribuicao_vendas', 'figure'),
    Input('selecao_marcas','value'), # quem está modificando/de onde eu quero pegar a informação/que tá fazendo um filtro.
)
def selecionar_marca(marca): 
    if marca == 'Todas':
        texto = 'Vendas de cada Produto por Loja'
        fig = px.bar(df, x="Produto", y="Quantidade", color="ID Loja", barmode="group")
        fig2 = px.scatter(df, x="Quantidade", y="Valor Final", color="Produto", size="Valor Unitário", size_max=60)
    else:
        # marca = Treinamentos
        # marca = Programação
        # filtrar as linhas da tabela onde a marca é igual a variável marca

        df_filtrada = df.loc[df['Marca'] == marca, :]    

        texto = f'Vendas de cada Produto por Loja da Marca {marca}'
        fig = px.bar(df_filtrada, x="Produto", y="Quantidade", color="ID Loja", barmode="group")
        fig2 = px.scatter(df_filtrada, x="Quantidade", y="Valor Final", color="Produto", size="Valor Unitário", size_max=60)  
    return texto, fig, fig2

# colocando o seu site (seu dashboard) no ar
if __name__ == '__main__':
    app.run_server(debug=False)
# Out:
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:8050/ (Press CTRL+C to quit)
# 127.0.0.1 - - [05/May/2022 21:25:26] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [05/May/2022 21:25:26] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [05/May/2022 21:25:26] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [05/May/2022 21:25:26] "GET /_favicon.ico?v=2.3.1 HTTP/1.1" 200 -
# 127.0.0.1 - - [05/May/2022 21:25:26] "GET /_dash-component-suites/dash/dcc/async-graph.js HTTP/1.1" 200 -
# 127.0.0.1 - - [05/May/2022 21:25:26] "GET /_dash-component-suites/dash/dcc/async-plotlyjs.js HTTP/1.1" 200 -
# 127.0.0.1 - - [05/May/2022 21:25:26] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [05/May/2022 21:25:29] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [05/May/2022 21:25:33] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [05/May/2022 21:25:35] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [05/May/2022 21:25:38] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [05/May/2022 21:25:40] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [05/May/2022 21:25:42] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [05/May/2022 21:25:44] "POST /_dash-update-component HTTP/1.1" 200 -

# %% [markdown]
# #### E se eu tivesse 2 botões editando os mesmos gráficos
#
# - Filtrar também pelo País

# %%
from dash import Dash, html, dcc, Input, Output
import plotly.express as px
import pandas as pd
import dash_auth

USUARIOS = {
    'Ferreira': '123456',
}


app = Dash(__name__) # criando o seu aplicativo Dash
auth = dash_auth.BasicAuth(app, USUARIOS)

# assume you have a "long-form" data frame
# see https://plotly.com/python/px-arguments/ for more options
df = pd.read_excel("Vendas.xlsx")

# df = tabela = dataframe

# plotly
fig = px.bar(df, x="Produto", y="Quantidade", color="ID Loja", barmode="group")
fig2 = px.scatter(df, x="Quantidade", y="Valor Final", color="Produto", size="Valor Unitário", size_max=60)


# lista_marcas = ["Treinamentos", "Programação", "Todas"]
lista_marcas = list(df["Marca"].unique())
lista_marcas.append("Todas")

lista_paises = list(df["País"].unique())
lista_paises.append("Todos")

# layout
app.layout = html.Div(children=[
    html.H1(children='Meu Dashboard'),

    html.Div(children='''
        Dashboard de Vendas em Python
    '''),
    
    html.H3(children="Vendas de cada Produto por Loja", id="subtitulo"),
    
    dcc.RadioItems(lista_marcas, value="Todas", id='selecao_marcas'),
    html.Div(children=[
        dcc.Dropdown(lista_paises, value="Todos", id='selecao_pais'),
    ], style={"width": "50%", "margin": "auto"}),
    
    dcc.Graph(id='vendas_por_loja',figure=fig),
    dcc.Graph(id='distribuicao_vendas', figure=fig2),
    
    
], style={"text-align": "center"})

# callbacks -> dar funcionalidade pro nosso dashboard (conecta os botões com os gráficos)
@app.callback(
    Output('subtitulo', 'children'), # eu quero modificar (eu quero que o botão do input modifique)
    Output('vendas_por_loja', 'figure'),
    Output('distribuicao_vendas', 'figure'),
    Input('selecao_marcas', 'value'), # quem está modificando/de onde eu quero pegar a informacao/que tá fazendo um filtro
    Input('selecao_pais', 'value'),
)
def selecionar_marca(marca, pais):
    if marca == "Todas" and pais == "Todos":
        texto = "Vendas de cada Produto por Loja"
        fig = px.bar(df, x="Produto", y="Quantidade", color="ID Loja", barmode="group")
        fig2 = px.scatter(df, x="Quantidade", y="Valor Final", color="Produto", size="Valor Unitário", size_max=60)
    else:
        df_filtrada = df
        if marca != "Todas":
            #filtrar de acordo com a marca
            df_filtrada = df_filtrada.loc[df_filtrada['Marca']==marca, :]
        if pais != "Todos":
            # filtrar de acordo com o pais
            df_filtrada = df_filtrada.loc[df_filtrada["País"]==pais, :]
        
        texto = f"Vendas de cada Produto por Loja da Marca {marca} e do País {pais}"
        fig = px.bar(df_filtrada, x="Produto", y="Quantidade", color="ID Loja", barmode="group")
        fig2 = px.scatter(df_filtrada, x="Quantidade", y="Valor Final", color="Produto", size="Valor Unitário", size_max=60)
    return texto, fig, fig2


# colocando o seu site (seu dashboard) no ar
if __name__ == '__main__':
    app.run_server(debug=False)
# Out:
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:8050/ (Press CTRL+C to quit)
# 127.0.0.1 - - [05/May/2022 22:08:18] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [05/May/2022 22:08:19] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [05/May/2022 22:08:19] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [05/May/2022 22:08:19] "GET /_favicon.ico?v=2.3.1 HTTP/1.1" 200 -
# 127.0.0.1 - - [05/May/2022 22:08:19] "GET /_dash-component-suites/dash/dcc/async-dropdown.js HTTP/1.1" 200 -
# 127.0.0.1 - - [05/May/2022 22:08:19] "GET /_dash-component-suites/dash/dcc/async-graph.js HTTP/1.1" 200 -
# 127.0.0.1 - - [05/May/2022 22:08:19] "GET /_dash-component-suites/dash/dcc/async-plotlyjs.js HTTP/1.1" 200 -
# 127.0.0.1 - - [05/May/2022 22:08:19] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [05/May/2022 22:08:21] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [05/May/2022 22:08:24] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [05/May/2022 22:08:27] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [05/May/2022 22:08:29] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [05/May/2022 22:08:32] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [05/May/2022 22:08:39] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [05/May/2022 22:08:42] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [05/May/2022 22:08:45] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [05/May/2022 22:08:48] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [05/May/2022 22:08:50] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [05/May/2022 22:08:52] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [05/May/2022 22:08:55] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [05/May/2022 22:08:57] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [05/May/2022 22:08:59] "POST /_dash-update-component HTTP/1.1" 200 -

# %% [markdown]
# #### Botões com opções dinâmicas

# %%
from dash import Dash, html, dcc, Input, Output
import plotly.express as px
import pandas as pd
import dash_auth

USUARIOS = {
    'Ferreira': '123456',
}


app = Dash(__name__) # criando o seu aplicativo Dash
auth = dash_auth.BasicAuth(app, USUARIOS)

# assume you have a "long-form" data frame
# see https://plotly.com/python/px-arguments/ for more options
df = pd.read_excel("Vendas.xlsx")

# df = tabela = dataframe

# plotly
fig = px.bar(df, x="Produto", y="Quantidade", color="ID Loja", barmode="group")
fig2 = px.scatter(df, x="Quantidade", y="Valor Final", color="Produto", size="Valor Unitário", size_max=60)


# lista_marcas = ["Treinamentos", "Programação", "Todas"]
lista_marcas = list(df["Marca"].unique())
lista_marcas.append("Todas")

lista_paises = list(df["País"].unique())
lista_paises.append("Todos")

# layout
app.layout = html.Div(children=[
    html.H1(children='Meu Dashboard'),

    html.Div(children='''
        Dashboard de Vendas em Python
    '''),
    
    html.H3(children="Vendas de cada Produto por Loja", id="subtitulo"),
    
    dcc.RadioItems(options=lista_marcas, value="Todas", id='selecao_marcas'),
    html.Div(children=[
        dcc.Dropdown(options=lista_paises, value="Todos", id='selecao_pais'),
    ], style={"width": "50%", "margin": "auto"}),
    
    dcc.Graph(id='vendas_por_loja',figure=fig),
    dcc.Graph(id='distribuicao_vendas', figure=fig2),
    
    
], style={"text-align": "center"})


@app.callback(
    Output('selecao_pais', 'options'),
    Input('selecao_marcas', 'value'),
)
def opcoes_pais(marca):
    # criar uma lógica que diga qual a lista de paises que ele vai pegar
    if marca == "Todas":
        nova_lista_paises = list(df["País"].unique())
        nova_lista_paises.append("Todos")
    else:
        df_filtrada = df.loc[df['Marca']==marca, :]
        nova_lista_paises = list(df_filtrada["País"].unique())
        nova_lista_paises.append("Todos")
    return nova_lista_paises





# callbacks -> dar funcionalidade pro nosso dashboard (conecta os botões com os gráficos)
@app.callback(
    Output('subtitulo', 'children'), # eu quero modificar (eu quero que o botão do input modifique)
    Output('vendas_por_loja', 'figure'),
    Output('distribuicao_vendas', 'figure'),
    Input('selecao_marcas', 'value'), # quem está modificando/de onde eu quero pegar a informacao/que tá fazendo um filtro
    Input('selecao_pais', 'value'),
)
def selecionar_marca(marca, pais):
    if marca == "Todas" and pais == "Todos":
        texto = "Vendas de cada Produto por Loja"
        fig = px.bar(df, x="Produto", y="Quantidade", color="ID Loja", barmode="group")
        fig2 = px.scatter(df, x="Quantidade", y="Valor Final", color="Produto", size="Valor Unitário", size_max=60)
    else:
        df_filtrada = df
        if marca != "Todas":
            #filtrar de acordo com a marca
            df_filtrada = df_filtrada.loc[df_filtrada['Marca']==marca, :]
        if pais != "Todos":
            # filtrar de acordo com o pais
            df_filtrada = df_filtrada.loc[df_filtrada["País"]==pais, :]
        
        texto = f"Vendas de cada Produto por Loja da Marca {marca} e do País {pais}"
        fig = px.bar(df_filtrada, x="Produto", y="Quantidade", color="ID Loja", barmode="group")
        fig2 = px.scatter(df_filtrada, x="Quantidade", y="Valor Final", color="Produto", size="Valor Unitário", size_max=60)
    return texto, fig, fig2


# colocando o seu site (seu dashboard) no ar
if __name__ == '__main__':
    app.run_server(debug=False)
# Out:
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:8050/ (Press CTRL+C to quit)
# 127.0.0.1 - - [05/May/2022 22:34:37] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [05/May/2022 22:34:37] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [05/May/2022 22:34:37] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [05/May/2022 22:34:37] "GET /_favicon.ico?v=2.3.1 HTTP/1.1" 200 -
# 127.0.0.1 - - [05/May/2022 22:34:37] "GET /_dash-component-suites/dash/dcc/async-dropdown.js HTTP/1.1" 200 -
# 127.0.0.1 - - [05/May/2022 22:34:37] "GET /_dash-component-suites/dash/dcc/async-graph.js HTTP/1.1" 200 -
# 127.0.0.1 - - [05/May/2022 22:34:37] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [05/May/2022 22:34:37] "GET /_dash-component-suites/dash/dcc/async-plotlyjs.js HTTP/1.1" 200 -
# 127.0.0.1 - - [05/May/2022 22:34:37] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [05/May/2022 22:35:06] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [05/May/2022 22:35:06] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [05/May/2022 22:35:12] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [05/May/2022 22:35:12] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [05/May/2022 22:35:17] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [05/May/2022 22:35:19] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [05/May/2022 22:35:19] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [05/May/2022 22:35:22] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [05/May/2022 22:35:22] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [05/May/2022 22:35:55] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [05/May/2022 22:35:55] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [05/May/2022 22:35:58] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [05/May/2022 22:35:59] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [05/May/2022 22:35:59] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [05/May/2022 22:36:04] "POST /_dash-update-component HTTP/1.1" 200 -
